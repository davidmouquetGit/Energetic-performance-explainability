# %%
import pandas as pd
import numpy as np
import scipy

import datetime
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
from lightgbm import LGBMRegressor
import lightgbm
import optuna
import warnings
from tqdm import TqdmExperimentalWarning
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import shap

# %% [markdown]
# ## Lecture des données

# %%
file_path = "data/dataprocess.csv"

data = pd.read_csv(file_path,sep=",",decimal=".")

data['DateProd'] = data['DateProd'].apply(lambda x: datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S"))
data.set_index('DateProd',inplace=True)

# %%
data.head()
# Out:
#                      conso_per_kg    type  var_quality  var_process  \
# DateProd
# 2025-01-01 00:00:00     1743.7111  prod_0       1090.0    44.868355
# 2025-01-01 00:06:00     1622.7773  prod_1       1090.0    46.858467
# 2025-01-01 00:12:00     1604.9292  prod_2       1090.0    46.823181
# 2025-01-01 00:18:00     1595.9277  prod_2       1090.0    45.785667
# 2025-01-01 00:24:00     1709.8407  prod_3       1090.0    44.991562
#
#                       var_dim1   var_dim2
# DateProd
# 2025-01-01 00:00:00  1031.0112  60.306684
# 2025-01-01 00:06:00  1038.0148  60.504509
# 2025-01-01 00:12:00  1034.7076  60.452483
# 2025-01-01 00:18:00  1032.9819  60.655019
# 2025-01-01 00:24:00  1034.5690  60.273794

# %%
features = ['type','var_quality','var_process','var_dim1','var_dim2']
target   = 'conso_per_kg'

data = data[[target]+features]

# %% [markdown]
# ## Suppression des outliers

# %%
cols = [target, 'var_quality','var_process','var_dim1','var_dim2']

# Création d'une grille 2 lignes × 3 colonnes
fig = make_subplots(rows=2, cols=3, subplot_titles=cols)

# Ajout des boxplots
for i, col in enumerate(cols):
    row = i // 3 + 1
    col_pos = i % 3 + 1
    fig.add_trace(go.Box(y=data[col], name=col), row=row, col=col_pos)

fig.update_layout(
    height=600, width=1000,
    title_text="Boxplots des 5 variables (avant suppression outliers)",
    showlegend=False
)

fig.show()

# %% [markdown]
# ![Box plot avant suppression outliers](images/box_plot_before_cleaning.png)

# %%
data = data[data.conso_per_kg>0] # On ne s'intéresse qu'aux consommations > 0
data = data[data.var_process>30]
data = data[data.var_dim1>500]
data = data[data.var_dim2>30]

# %%
# Création d'une grille 2 lignes × 3 colonnes
fig = make_subplots(rows=2, cols=3, subplot_titles=cols)

# Ajout des boxplots
for i, col in enumerate(cols):
    row = i // 3 + 1
    col_pos = i % 3 + 1
    fig.add_trace(go.Box(y=data[col], name=col), row=row, col=col_pos)

fig.update_layout(
    height=600, width=1000,
    title_text="Boxplots des 5 variables (après suppression outliers)",
    showlegend=False
)

fig.show()

# %% [markdown]
# ![Box plot avant suppression outliers](images/box_plot_after_cleaning.png)

# %% [markdown]
# ## Construction du preprocesseur

# %%
def BuildPrepro(data:pd.DataFrame, features:list):

    """
    Function that build the preprocessor of the model pipeline
    Taking into account possible categorical variables

    """

    from sklearn.preprocessing import OneHotEncoder
    from sklearn.compose import ColumnTransformer
    from sklearn.preprocessing import StandardScaler
    import numpy as np
    
    num_feat = [f for f in data[features].columns if data.dtypes[f]==np.float64]
    cat_feat = [f for f in data[features].columns if data.dtypes[f]==object]

    if len(cat_feat)>0:
        num_prepro  = StandardScaler()
        cat_prepro  = OneHotEncoder(handle_unknown='ignore')
        prepro =  ColumnTransformer([('num',num_prepro,num_feat),('cat',cat_prepro, cat_feat)])
    else:
        num_prepro = StandardScaler()
        prepro =  ColumnTransformer([('num',num_prepro,num_feat)])

    return prepro

# %% [markdown]
# ## Réduction de dimensionnalité

# %%
nb_type = len(data.type.unique())
print(f"nombre de catégories {nb_type}")
# Out:
# nombre de catégories 90

# %% [markdown]
# Le nombre de catégories est assez élevé. On effectue une réduction de dimensionnalité afin de ne conserver que les catégories les plus influentes.
# Ici, j'utilise la propriété feature_importance des arbres de régression pour classer le poids des catégories

# %%
y = data[target]
X = data[features]
prepro = BuildPrepro(data = data, features = features)
X_onehot = prepro.fit_transform(X)
model_reduction =DecisionTreeRegressor()
model_reduction.fit(X_onehot, y)
# Out:
# DecisionTreeRegressor()

# %%
df_feat_importance = pd.DataFrame(data={"features":prepro.get_feature_names_out().tolist(), # dataframe avec le poids obtenus pour chaque features
                                        "importance":model_reduction.feature_importances_})

# %%
df_feat_importance.head(7)
# Out:
#             features  importance
# 0   num__var_quality    0.086154
# 1   num__var_process    0.093782
# 2      num__var_dim1    0.682526
# 3      num__var_dim2    0.054273
# 4   cat__type_prod_0    0.001013
# 5   cat__type_prod_1    0.004810
# 6  cat__type_prod_10    0.000505

# %%
# On ne regarde que les features qui sont associées à un produit
df_feat_importance_prod = df_feat_importance[df_feat_importance['features'].str.contains('prod')]
df_feat_importance_prod.sort_values(by='importance',ascending=False,inplace=True)
df_feat_importance_prod['perc'] = 100*df_feat_importance_prod['importance']/df_feat_importance_prod['importance'].sum()
df_feat_importance_prod['percum'] = df_feat_importance_prod['perc'].cumsum()

# on garde les catégories dont le cumul de l'importance est < 80 %
categorie_conservees = df_feat_importance_prod[df_feat_importance_prod.percum<80]['features'].to_list()

# on supprime la chaine "cat__type_" ajoutée par le transformeur
categorie_conservees =  [c.replace("cat__type_", "") for c in categorie_conservees] 

# On crée un dictionnaire pour mapper les types de produits les plus influents dans le dataframe "data"

dico_map_prod = {
    p: p if p in categorie_conservees else 'autres'
    for p in data.type.unique()
}

data['type'] = data['type'].map(dico_map_prod)

# %% [markdown]
# ## Construction du modèle
# Ici in utilise un lightgbm

# %%
def objective(trial,X_trs,Y):

    from sklearn.model_selection import train_test_split
    from sklearn.metrics import root_mean_squared_error
    import numpy as np
    import warnings
    warnings.simplefilter('ignore')

    train_x, test_x, train_y, test_y = train_test_split(X_trs, Y, test_size=0.2,random_state=42)

    callbacks = [lightgbm.early_stopping(100, verbose=0), lightgbm.log_evaluation(period=0)]

    model = LGBMRegressor(verbosity = -1)

    
    param = { 
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.5,0.6,0.7]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.02,0.04,0.08,0.12]),
        'max_depth': trial.suggest_categorical('max_depth', [4,5,6]),
        'n_estimators':trial.suggest_int('n_estimators',200,500,10),
        'num_leaves' : trial.suggest_int('num_leaves',100,200,20),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_categorical('subsample', [0.7,0.8,0.9])
    }

    fixed_hp =   {
            'metric': 'rmse', 
            'random_state': 48,
            'verbose': -1
        }

    for p, pv in fixed_hp.items():
        param[p] = pv

    model = LGBMRegressor(**param)

    model.fit(train_x,train_y,eval_set=[(test_x,test_y)],callbacks=callbacks)

    preds_train = model.predict(train_x)  
    rmse_train = root_mean_squared_error(train_y, preds_train)
    preds_test = model.predict(test_x)
    rmse_test = root_mean_squared_error(test_y, preds_test)

    alpha_overfit = 0.4
    score_final = alpha_overfit*rmse_train + (1-alpha_overfit)*np.abs(rmse_train-rmse_test)
    
    return score_final

# %%
def FindHyperParams(data:pd.DataFrame, target:str, features:list):


    optuna.logging.set_verbosity(optuna.logging.INFO)
    warnings.filterwarnings("ignore", category=TqdmExperimentalWarning)


    data.dropna(inplace=True)
    Y  = data[target]
    X  = data[features]

    prepro = BuildPrepro(data = data, features = features)

    X_trs = prepro.fit_transform(X)
    
    study = optuna.create_study(direction='minimize')

    Ntrial = 200


    study.optimize(lambda trial: objective(trial, X_trs, Y), n_trials = Ntrial)
    best_params = study.best_trial.params

    return best_params

# %%
best_params = FindHyperParams(data=data,target=target,features=features)
# Out:
# [I 2025-10-10 10:06:55,624] A new study created in memory with name: no-name-fec09477-c9a8-4f7b-8513-18ce0b8d126b
# [I 2025-10-10 10:06:56,966] Trial 0 finished with value: 132.20001114920157 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 180, 'reg_alpha': 0.22053948898674125, 'reg_lambda': 2.9219853471912747, 'subsample': 0.9}. Best is trial 0 with value: 132.20001114920157.
# [I 2025-10-10 10:06:57,946] Trial 1 finished with value: 132.36823916229034 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.04, 'max_depth': 6, 'n_estimators': 270, 'num_leaves': 140, 'reg_alpha': 0.024501282431078325, 'reg_lambda': 0.004319592894011409, 'subsample': 0.8}. Best is trial 0 with value: 132.20001114920157.
# [I 2025-10-10 10:06:58,788] Trial 2 finished with value: 132.10860970076016 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.013147189511522966, 'reg_lambda': 0.0014468553824574823, 'subsample': 0.8}. Best is trial 2 with value: 132.10860970076016.
# [I 2025-10-10 10:06:59,308] Trial 3 finished with value: 140.9169020377677 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 210, 'num_leaves': 140, 'reg_alpha': 0.0019591841860192587, 'reg_lambda': 0.0454082856576947, 'subsample': 0.7}. Best is trial 2 with value: 132.10860970076016.
# [I 2025-10-10 10:06:59,851] Trial 4 finished with value: 135.10552901027623 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 310, 'num_leaves': 140, 'reg_alpha': 1.7154511681891134, 'reg_lambda': 0.1338143077346601, 'subsample': 0.9}. Best is trial 2 with value: 132.10860970076016.
# [I 2025-10-10 10:07:00,821] Trial 5 finished with value: 131.82627223967265 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.04, 'max_depth': 6, 'n_estimators': 350, 'num_leaves': 120, 'reg_alpha': 3.1972905736687216, 'reg_lambda': 0.8647495922417893, 'subsample': 0.7}. Best is trial 5 with value: 131.82627223967265.
# [I 2025-10-10 10:07:01,282] Trial 6 finished with value: 133.01521933645006 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 4, 'n_estimators': 260, 'num_leaves': 120, 'reg_alpha': 0.1141987398106661, 'reg_lambda': 0.004318665142337832, 'subsample': 0.8}. Best is trial 5 with value: 131.82627223967265.
# [I 2025-10-10 10:07:01,787] Trial 7 finished with value: 136.05528524374085 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 270, 'num_leaves': 200, 'reg_alpha': 0.013205146443483824, 'reg_lambda': 1.3806982545198614, 'subsample': 0.9}. Best is trial 5 with value: 131.82627223967265.
# [I 2025-10-10 10:07:02,354] Trial 8 finished with value: 132.533529451492 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 4, 'n_estimators': 320, 'num_leaves': 140, 'reg_alpha': 0.3351123982383106, 'reg_lambda': 7.557812400581649, 'subsample': 0.8}. Best is trial 5 with value: 131.82627223967265.
# [I 2025-10-10 10:07:03,061] Trial 9 finished with value: 134.0127891455225 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 410, 'num_leaves': 100, 'reg_alpha': 0.0021684830690318862, 'reg_lambda': 5.385734111975231, 'subsample': 0.8}. Best is trial 5 with value: 131.82627223967265.
# [I 2025-10-10 10:07:04,560] Trial 10 finished with value: 132.8001562949679 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.02, 'max_depth': 6, 'n_estimators': 500, 'num_leaves': 100, 'reg_alpha': 4.646962761090621, 'reg_lambda': 0.42264384915074477, 'subsample': 0.7}. Best is trial 5 with value: 131.82627223967265.
# [I 2025-10-10 10:07:05,390] Trial 11 finished with value: 131.80353079967227 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 160, 'reg_alpha': 0.009376853541682351, 'reg_lambda': 0.02224127624436943, 'subsample': 0.7}. Best is trial 11 with value: 131.80353079967227.
# [I 2025-10-10 10:07:06,460] Trial 12 finished with value: 133.01002162906377 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.12, 'max_depth': 6, 'n_estimators': 360, 'num_leaves': 180, 'reg_alpha': 1.0328530107701916, 'reg_lambda': 0.06252853511869448, 'subsample': 0.7}. Best is trial 11 with value: 131.80353079967227.
# [I 2025-10-10 10:07:07,840] Trial 13 finished with value: 132.17323223178732 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 160, 'reg_alpha': 0.05682886789462248, 'reg_lambda': 0.01494299441017921, 'subsample': 0.7}. Best is trial 11 with value: 131.80353079967227.
# [I 2025-10-10 10:07:09,018] Trial 14 finished with value: 131.7367946836535 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.04, 'max_depth': 6, 'n_estimators': 360, 'num_leaves': 120, 'reg_alpha': 6.952324012734367, 'reg_lambda': 0.35834467073480775, 'subsample': 0.7}. Best is trial 14 with value: 131.7367946836535.
# [I 2025-10-10 10:07:10,082] Trial 15 finished with value: 133.29673115032335 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.12, 'max_depth': 6, 'n_estimators': 380, 'num_leaves': 160, 'reg_alpha': 9.326950132246612, 'reg_lambda': 0.197745090244228, 'subsample': 0.7}. Best is trial 14 with value: 131.7367946836535.
# [I 2025-10-10 10:07:11,241] Trial 16 finished with value: 131.53256890016982 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 470, 'num_leaves': 120, 'reg_alpha': 0.006637075562988975, 'reg_lambda': 0.02272255053013888, 'subsample': 0.7}. Best is trial 16 with value: 131.53256890016982.
# [I 2025-10-10 10:07:12,728] Trial 17 finished with value: 132.31387708479502 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.08, 'max_depth': 6, 'n_estimators': 490, 'num_leaves': 120, 'reg_alpha': 0.6580791826746825, 'reg_lambda': 0.25874031464772684, 'subsample': 0.7}. Best is trial 16 with value: 131.53256890016982.
# [I 2025-10-10 10:07:13,738] Trial 18 finished with value: 131.72040248736207 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 460, 'num_leaves': 100, 'reg_alpha': 0.0013259271439200772, 'reg_lambda': 0.012798213661430637, 'subsample': 0.7}. Best is trial 16 with value: 131.53256890016982.
# [I 2025-10-10 10:07:14,861] Trial 19 finished with value: 131.4905335714137 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 460, 'num_leaves': 100, 'reg_alpha': 0.0010923392679958825, 'reg_lambda': 0.009032867098623528, 'subsample': 0.7}. Best is trial 19 with value: 131.4905335714137.
# [I 2025-10-10 10:07:16,022] Trial 20 finished with value: 131.51391265586645 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 470, 'num_leaves': 100, 'reg_alpha': 0.004723990924333137, 'reg_lambda': 0.004708271625746632, 'subsample': 0.9}. Best is trial 19 with value: 131.4905335714137.
# [I 2025-10-10 10:07:17,037] Trial 21 finished with value: 131.45611027709558 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 100, 'reg_alpha': 0.005257910624266572, 'reg_lambda': 0.003938974470882316, 'subsample': 0.9}. Best is trial 21 with value: 131.45611027709558.
# [I 2025-10-10 10:07:18,098] Trial 22 finished with value: 131.29127149557655 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 100, 'reg_alpha': 0.00463693654649293, 'reg_lambda': 0.0012166508378333141, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:19,139] Trial 23 finished with value: 131.4831181324128 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 100, 'reg_alpha': 0.002995686730242696, 'reg_lambda': 0.001724212352121401, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:20,153] Trial 24 finished with value: 131.48242278611258 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 100, 'reg_alpha': 0.003601585254422037, 'reg_lambda': 0.001419960229459217, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:21,172] Trial 25 finished with value: 131.43171989247742 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 120, 'reg_alpha': 0.03408390075655083, 'reg_lambda': 0.0010834454575858459, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:22,193] Trial 26 finished with value: 131.412096592872 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 120, 'reg_alpha': 0.029819965340179985, 'reg_lambda': 0.0010612449559210197, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:23,227] Trial 27 finished with value: 135.0812072293303 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 120, 'reg_alpha': 0.024299848837894395, 'reg_lambda': 0.0020414560296578023, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:24,276] Trial 28 finished with value: 131.47730678935693 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 120, 'reg_alpha': 0.04489837704189384, 'reg_lambda': 0.002922608537872155, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:25,096] Trial 29 finished with value: 131.4647057909408 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 330, 'num_leaves': 120, 'reg_alpha': 0.14032184802143136, 'reg_lambda': 0.007010205334136665, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:26,021] Trial 30 finished with value: 131.37899104025246 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 180, 'reg_alpha': 0.05542168251761969, 'reg_lambda': 0.0010198445171407681, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:26,989] Trial 31 finished with value: 131.37899055721397 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 180, 'reg_alpha': 0.057684619598743284, 'reg_lambda': 0.001031840794700631, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:27,975] Trial 32 finished with value: 131.48922043635267 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 180, 'reg_alpha': 0.07493159728527606, 'reg_lambda': 0.002254131700599636, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:29,157] Trial 33 finished with value: 131.4153022754894 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 480, 'num_leaves': 200, 'reg_alpha': 0.1998512321473473, 'reg_lambda': 0.0010281727902677266, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:30,194] Trial 34 finished with value: 131.5068929199388 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 180, 'reg_alpha': 0.022414086106839464, 'reg_lambda': 0.002339096353199553, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:31,191] Trial 35 finished with value: 135.4801570848415 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 200, 'reg_alpha': 0.015828563522046833, 'reg_lambda': 0.006173038272495178, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:32,063] Trial 36 finished with value: 131.373280722518 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 160, 'reg_alpha': 0.4537558433142497, 'reg_lambda': 0.0010281745919226534, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:32,918] Trial 37 finished with value: 131.52662863664617 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 160, 'reg_alpha': 0.30691962872646117, 'reg_lambda': 0.0033259945692268246, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:33,476] Trial 38 finished with value: 132.36448984660268 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 200, 'num_leaves': 180, 'reg_alpha': 0.6410412948265792, 'reg_lambda': 0.0017540281162155586, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:34,256] Trial 39 finished with value: 137.00332327825313 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.02, 'max_depth': 4, 'n_estimators': 450, 'num_leaves': 180, 'reg_alpha': 0.09000019117837851, 'reg_lambda': 0.03620179730675657, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:35,005] Trial 40 finished with value: 131.42495345517392 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 340, 'num_leaves': 160, 'reg_alpha': 0.4267585221178361, 'reg_lambda': 0.0029994075277020903, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:35,874] Trial 41 finished with value: 131.3733036024175 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.15968436827443672, 'reg_lambda': 0.001178559137803862, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:36,422] Trial 42 finished with value: 132.0459774436301 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 240, 'num_leaves': 140, 'reg_alpha': 2.004888810106041, 'reg_lambda': 0.001002938436260584, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:37,290] Trial 43 finished with value: 131.3732984671938 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 200, 'reg_alpha': 0.14920622666742495, 'reg_lambda': 0.0016681814961404771, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:37,818] Trial 44 finished with value: 135.32259741250053 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 300, 'num_leaves': 200, 'reg_alpha': 0.17330879922394365, 'reg_lambda': 0.0016673509127583218, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:38,629] Trial 45 finished with value: 131.5150154313806 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 200, 'reg_alpha': 0.2753055633115765, 'reg_lambda': 0.005392617054563141, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:39,499] Trial 46 finished with value: 131.33561302337466 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.5316039460727778, 'reg_lambda': 0.008734347424311775, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:40,194] Trial 47 finished with value: 131.5491706067815 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.12, 'max_depth': 4, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.5620019306162869, 'reg_lambda': 0.011185319824785723, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:40,959] Trial 48 finished with value: 132.79194795465793 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 5, 'n_estimators': 350, 'num_leaves': 140, 'reg_alpha': 2.0066641123663898, 'reg_lambda': 0.007811914024174578, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:42,035] Trial 49 finished with value: 132.16123233186434 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.08, 'max_depth': 6, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 1.0787830749913925, 'reg_lambda': 0.0029003789430001444, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:42,958] Trial 50 finished with value: 136.19031723495607 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 160, 'reg_alpha': 0.12028753511901431, 'reg_lambda': 0.07917355976131704, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:43,866] Trial 51 finished with value: 131.4614351808143 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 160, 'reg_alpha': 1.0589250124431802, 'reg_lambda': 0.0014719314256270934, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:44,738] Trial 52 finished with value: 131.47160013561276 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 180, 'reg_alpha': 0.44726211528029214, 'reg_lambda': 0.00226647018271921, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:45,673] Trial 53 finished with value: 131.47357773134343 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.2164652797651091, 'reg_lambda': 0.003927848971304674, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:46,634] Trial 54 finished with value: 131.79699732873755 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 200, 'reg_alpha': 0.7950177723906235, 'reg_lambda': 1.1242067598537955, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:47,609] Trial 55 finished with value: 132.5026862822484 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 160, 'reg_alpha': 0.08009274032721328, 'reg_lambda': 2.3865367483690276, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:48,944] Trial 56 finished with value: 131.88658133909223 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.08, 'max_depth': 6, 'n_estimators': 410, 'num_leaves': 160, 'reg_alpha': 0.008625590971619525, 'reg_lambda': 0.019737205160573895, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:50,095] Trial 57 finished with value: 131.76017209343019 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 460, 'num_leaves': 140, 'reg_alpha': 3.086338026958928, 'reg_lambda': 0.001412054303374256, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:50,959] Trial 58 finished with value: 133.64085200795915 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 430, 'num_leaves': 180, 'reg_alpha': 0.3831853807912625, 'reg_lambda': 0.004669952657856209, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:51,615] Trial 59 finished with value: 131.65988930276205 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 300, 'num_leaves': 200, 'reg_alpha': 0.1422943819205345, 'reg_lambda': 0.12278776103248393, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:52,717] Trial 60 finished with value: 131.3610917440034 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 500, 'num_leaves': 140, 'reg_alpha': 0.24860997405538898, 'reg_lambda': 0.0015070104673132166, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:53,673] Trial 61 finished with value: 131.43940589223922 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.2639596893103472, 'reg_lambda': 0.0015086518376796866, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:54,734] Trial 62 finished with value: 131.5098134564616 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 480, 'num_leaves': 140, 'reg_alpha': 0.17267881813301025, 'reg_lambda': 0.0027103183957995556, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:56,023] Trial 63 finished with value: 131.72384760566837 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 500, 'num_leaves': 140, 'reg_alpha': 1.4272064292163387, 'reg_lambda': 0.0013364232468500337, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:56,807] Trial 64 finished with value: 131.45917728026564 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 360, 'num_leaves': 160, 'reg_alpha': 0.057739729047775634, 'reg_lambda': 0.002010269900334725, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:57,910] Trial 65 finished with value: 131.48112286325548 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 490, 'num_leaves': 120, 'reg_alpha': 0.10210090552938103, 'reg_lambda': 0.00380242396625724, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:07:59,152] Trial 66 finished with value: 133.66615471029158 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.12, 'max_depth': 6, 'n_estimators': 420, 'num_leaves': 160, 'reg_alpha': 0.8149205983226083, 'reg_lambda': 0.0013521766755672327, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:00,172] Trial 67 finished with value: 131.8909159765585 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.48194415930705914, 'reg_lambda': 0.03702498970067243, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:01,112] Trial 68 finished with value: 131.52889581568465 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 180, 'reg_alpha': 0.3078882155271014, 'reg_lambda': 0.0021301028634874023, 'subsample': 0.7}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:02,142] Trial 69 finished with value: 131.45273882302212 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 460, 'num_leaves': 120, 'reg_alpha': 0.0022251058839917845, 'reg_lambda': 0.001286158068365226, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:03,139] Trial 70 finished with value: 131.3617583930413 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 160, 'reg_alpha': 0.24640684239519542, 'reg_lambda': 0.009252884331761316, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:04,043] Trial 71 finished with value: 131.5877860380865 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 160, 'reg_alpha': 0.1330842046911218, 'reg_lambda': 0.017877594418534835, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:05,035] Trial 72 finished with value: 131.42098910527852 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 160, 'reg_alpha': 0.2093546326218475, 'reg_lambda': 0.009307750423129677, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:06,005] Trial 73 finished with value: 131.44610778796132 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 180, 'reg_alpha': 0.357004683768495, 'reg_lambda': 0.0017740928099758695, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:06,876] Trial 74 finished with value: 131.4958957282727 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 160, 'reg_alpha': 0.16304447654449636, 'reg_lambda': 0.002683208720668578, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:07,824] Trial 75 finished with value: 135.07969147314492 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 140, 'reg_alpha': 0.06628888606250292, 'reg_lambda': 0.02757344973357849, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:08,752] Trial 76 finished with value: 131.43171826333102 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 200, 'reg_alpha': 0.0404156938423921, 'reg_lambda': 0.0011415915833450046, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:09,569] Trial 77 finished with value: 131.53181042682928 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 140, 'reg_alpha': 0.10804581910120918, 'reg_lambda': 0.005294864950510688, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:10,259] Trial 78 finished with value: 134.0653767803128 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 390, 'num_leaves': 180, 'reg_alpha': 0.017266772181542312, 'reg_lambda': 0.5951221832804996, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:11,301] Trial 79 finished with value: 131.76387411469454 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 470, 'num_leaves': 160, 'reg_alpha': 0.2685957357170115, 'reg_lambda': 0.054459725540034344, 'subsample': 0.7}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:12,615] Trial 80 finished with value: 132.54588667419034 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.08, 'max_depth': 6, 'n_estimators': 440, 'num_leaves': 120, 'reg_alpha': 0.5430198710081815, 'reg_lambda': 0.003548062831386066, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:13,630] Trial 81 finished with value: 131.37899225243672 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 180, 'reg_alpha': 0.04294319331034799, 'reg_lambda': 0.0010375245885784461, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:14,665] Trial 82 finished with value: 131.4315602500302 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 180, 'reg_alpha': 0.23638519473418013, 'reg_lambda': 0.0017807459930242425, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:15,709] Trial 83 finished with value: 131.39663202899595 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 200, 'reg_alpha': 0.05429503240311678, 'reg_lambda': 0.0011844517351456416, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:16,706] Trial 84 finished with value: 131.46639392505753 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 160, 'reg_alpha': 0.7214858668140661, 'reg_lambda': 0.0016866990468442302, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:17,763] Trial 85 finished with value: 131.46405504156593 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 460, 'num_leaves': 180, 'reg_alpha': 0.029992445049064984, 'reg_lambda': 0.002457032181043969, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:18,704] Trial 86 finished with value: 132.5362615614185 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 140, 'reg_alpha': 0.09271447784173496, 'reg_lambda': 0.0010254059308368458, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:19,865] Trial 87 finished with value: 134.03517388504352 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 480, 'num_leaves': 180, 'reg_alpha': 0.16912495599686383, 'reg_lambda': 0.0020854586115035363, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:20,725] Trial 88 finished with value: 131.3755313250007 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 350, 'num_leaves': 100, 'reg_alpha': 0.00142250837018614, 'reg_lambda': 9.892345212074142, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:21,437] Trial 89 finished with value: 131.90338619022242 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 320, 'num_leaves': 100, 'reg_alpha': 0.0012488982051565814, 'reg_lambda': 0.20279442891855642, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:22,077] Trial 90 finished with value: 132.10069971570658 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 4, 'n_estimators': 360, 'num_leaves': 100, 'reg_alpha': 0.004945115264178484, 'reg_lambda': 3.058578678647689, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:22,921] Trial 91 finished with value: 131.39924996123037 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 100, 'reg_alpha': 0.0018470774512333815, 'reg_lambda': 0.001346570120277037, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:23,662] Trial 92 finished with value: 131.42495378843003 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 340, 'num_leaves': 100, 'reg_alpha': 0.00299611813861119, 'reg_lambda': 0.003142508120139212, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:24,638] Trial 93 finished with value: 131.7177214754779 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 100, 'reg_alpha': 0.0017912454651665736, 'reg_lambda': 9.991746213377757, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:25,437] Trial 94 finished with value: 131.2974512495107 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 140, 'reg_alpha': 0.009923331990774322, 'reg_lambda': 0.3554504533939996, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:26,259] Trial 95 finished with value: 131.80276008512112 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 140, 'reg_alpha': 0.006834199707565851, 'reg_lambda': 1.8559841253710192, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:27,106] Trial 96 finished with value: 132.7494442074486 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 5, 'n_estimators': 360, 'num_leaves': 140, 'reg_alpha': 0.009124004268890224, 'reg_lambda': 6.1776594495587736, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:27,855] Trial 97 finished with value: 131.62237862728685 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 340, 'num_leaves': 140, 'reg_alpha': 0.003308469913791063, 'reg_lambda': 0.33556752368571646, 'subsample': 0.7}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:28,608] Trial 98 finished with value: 131.49376723132002 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 350, 'num_leaves': 140, 'reg_alpha': 0.010524268865143672, 'reg_lambda': 0.8705617725178623, 'subsample': 0.8}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:29,673] Trial 99 finished with value: 131.96709613804921 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.08, 'max_depth': 6, 'n_estimators': 380, 'num_leaves': 120, 'reg_alpha': 0.0024596686025936104, 'reg_lambda': 3.8103496564824177, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:30,592] Trial 100 finished with value: 131.53549954347562 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 160, 'reg_alpha': 0.3951365123339271, 'reg_lambda': 0.09271960779054926, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:31,485] Trial 101 finished with value: 131.35034535102085 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 140, 'reg_alpha': 0.004308578258334477, 'reg_lambda': 0.01338528672750477, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:32,356] Trial 102 finished with value: 131.31733837564946 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.01142650484387135, 'reg_lambda': 0.011539694974088285, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:33,268] Trial 103 finished with value: 131.35146989042346 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.0038368854786154038, 'reg_lambda': 0.013157701861672368, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:34,142] Trial 104 finished with value: 131.3514680260718 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.004013803699120103, 'reg_lambda': 0.013319491394712956, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:35,094] Trial 105 finished with value: 131.35146828360487 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.006816973656122261, 'reg_lambda': 0.013275155170681091, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:35,990] Trial 106 finished with value: 131.3449078458662 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.00404154197602119, 'reg_lambda': 0.01546470485944459, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:36,864] Trial 107 finished with value: 131.34491142072343 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.004035721079298363, 'reg_lambda': 0.015090878691374385, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:37,695] Trial 108 finished with value: 131.89072836983127 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.003804588568128873, 'reg_lambda': 0.012074374807664696, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:38,545] Trial 109 finished with value: 131.34491737036817 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.006143727795494745, 'reg_lambda': 0.014451619186323449, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:39,371] Trial 110 finished with value: 131.3922907992726 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 140, 'reg_alpha': 0.006231538545020988, 'reg_lambda': 0.015601892275467738, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:40,221] Trial 111 finished with value: 131.73360770470757 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.003773128946555189, 'reg_lambda': 0.027866795663171795, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:41,095] Trial 112 finished with value: 131.3449269361157 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.012032069854164305, 'reg_lambda': 0.01340749778058854, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:41,942] Trial 113 finished with value: 131.34492189297288 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.011909587690248963, 'reg_lambda': 0.01393628964022427, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:42,847] Trial 114 finished with value: 131.50120728889345 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 140, 'reg_alpha': 0.011507698698517118, 'reg_lambda': 0.007286984343636355, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:43,717] Trial 115 finished with value: 131.49837307290542 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.006998426647646328, 'reg_lambda': 0.02452599500181496, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:44,524] Trial 116 finished with value: 131.4016568173176 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 140, 'reg_alpha': 0.013099058216771722, 'reg_lambda': 0.01670884125207324, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:45,408] Trial 117 finished with value: 135.6088176500542 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 140, 'reg_alpha': 0.01769255429998263, 'reg_lambda': 0.019684231357935563, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:46,131] Trial 118 finished with value: 131.8059685370354 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 4, 'n_estimators': 420, 'num_leaves': 140, 'reg_alpha': 0.0057864981399345485, 'reg_lambda': 0.010446581770573487, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:47,019] Trial 119 finished with value: 131.35146843355346 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.008179990004942793, 'reg_lambda': 0.013251405316068944, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:48,020] Trial 120 finished with value: 131.45112614236595 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.0045237811063857936, 'reg_lambda': 0.03683159276124953, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:48,940] Trial 121 finished with value: 131.35146962826627 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.007845918377792405, 'reg_lambda': 0.0131489818695517, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:49,841] Trial 122 finished with value: 131.5011901439613 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 140, 'reg_alpha': 0.01472204418218024, 'reg_lambda': 0.008531393097948821, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:50,723] Trial 123 finished with value: 131.49586200428348 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.021098760621131366, 'reg_lambda': 0.006491393682376007, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:51,554] Trial 124 finished with value: 131.39230729266387 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 140, 'reg_alpha': 0.004535503625761992, 'reg_lambda': 0.013695837931372171, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:52,383] Trial 125 finished with value: 131.35888028668322 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 140, 'reg_alpha': 0.010722026740332668, 'reg_lambda': 0.010751272510990346, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:53,237] Trial 126 finished with value: 132.3630443434133 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.005558971841723221, 'reg_lambda': 0.021819953869083256, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:54,365] Trial 127 finished with value: 131.97394448138144 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.08, 'max_depth': 6, 'n_estimators': 410, 'num_leaves': 120, 'reg_alpha': 0.008303428752871878, 'reg_lambda': 0.016377625271698726, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:55,335] Trial 128 finished with value: 131.78553051216053 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.00242553221517886, 'reg_lambda': 0.026259569836522376, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:56,242] Trial 129 finished with value: 131.53136029495676 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 140, 'reg_alpha': 0.007587499256581906, 'reg_lambda': 0.03182304944017522, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:57,052] Trial 130 finished with value: 131.64357805551833 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 140, 'reg_alpha': 0.0027580793128064874, 'reg_lambda': 0.005712592457620754, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:57,921] Trial 131 finished with value: 131.35145889415338 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.007930066900789436, 'reg_lambda': 0.014089684358505623, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:58,783] Trial 132 finished with value: 131.31925675516587 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.012079001840871633, 'reg_lambda': 0.01036628178180794, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:08:59,641] Trial 133 finished with value: 131.52660098907265 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.012855710937192625, 'reg_lambda': 0.007833079000878939, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:09:00,565] Trial 134 finished with value: 131.301097303833 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 410, 'num_leaves': 140, 'reg_alpha': 0.004468376182762299, 'reg_lambda': 0.010079260308908334, 'subsample': 0.9}. Best is trial 22 with value: 131.29127149557655.
# [I 2025-10-10 10:09:01,527] Trial 135 finished with value: 131.22750304410494 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.00432489737749168, 'reg_lambda': 0.010144332150460135, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:02,453] Trial 136 finished with value: 132.05048667828606 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.005078898996540912, 'reg_lambda': 0.009988215702816465, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:03,388] Trial 137 finished with value: 131.56656225567693 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 140, 'reg_alpha': 0.009984852977545982, 'reg_lambda': 0.019657453750482723, 'subsample': 0.7}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:04,321] Trial 138 finished with value: 131.47353174173824 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.019657218286628676, 'reg_lambda': 0.008171428538647602, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:05,237] Trial 139 finished with value: 135.63404442162002 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 120, 'reg_alpha': 0.003223109796233122, 'reg_lambda': 0.0111794032434748, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:05,989] Trial 140 finished with value: 131.85441568743175 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 4, 'n_estimators': 410, 'num_leaves': 140, 'reg_alpha': 0.00611436612852874, 'reg_lambda': 0.006421119754663227, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:06,836] Trial 141 finished with value: 131.34490713153215 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.003983773753211808, 'reg_lambda': 0.015539781838032125, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# ...
# [I 2025-10-10 10:09:17,077] Trial 153 finished with value: 131.573630164215 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 360, 'num_leaves': 140, 'reg_alpha': 0.00273882420510075, 'reg_lambda': 0.018702070808292382, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:17,989] Trial 154 finished with value: 131.29967242064373 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 140, 'reg_alpha': 0.003318967191491044, 'reg_lambda': 0.010702059174833434, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:18,946] Trial 155 finished with value: 132.3534977618585 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 140, 'reg_alpha': 0.02567570587181932, 'reg_lambda': 0.008768455763754176, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:19,756] Trial 156 finished with value: 131.563424958456 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 370, 'num_leaves': 140, 'reg_alpha': 0.011877376771955637, 'reg_lambda': 0.15626151387668596, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:20,686] Trial 157 finished with value: 131.70451819957867 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 120, 'reg_alpha': 0.009501718095032304, 'reg_lambda': 0.011904201424832056, 'subsample': 0.7}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:21,515] Trial 158 finished with value: 131.53180336228073 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 380, 'num_leaves': 140, 'reg_alpha': 0.005005552685374204, 'reg_lambda': 0.006780552505672973, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:22,396] Trial 159 finished with value: 131.68059745521276 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 140, 'reg_alpha': 0.0016592387344799707, 'reg_lambda': 0.49732940152681254, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:23,253] Trial 160 finished with value: 131.5266289443593 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 390, 'num_leaves': 140, 'reg_alpha': 0.0023827132324331984, 'reg_lambda': 0.005307917540781877, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:24,194] Trial 161 finished with value: 131.29966512396965 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 140, 'reg_alpha': 0.0034424118768200114, 'reg_lambda': 0.011212086898482477, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:25,123] Trial 162 finished with value: 131.29967068871218 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 140, 'reg_alpha': 0.003925595729837312, 'reg_lambda': 0.010819695093248548, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:26,041] Trial 163 finished with value: 131.47164260390844 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 420, 'num_leaves': 140, 'reg_alpha': 0.0039294287522120995, 'reg_lambda': 0.008791870978224425, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:27,018] Trial 164 finished with value: 131.2799915603297 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0029081831021843807, 'reg_lambda': 0.010677826828725697, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:27,990] Trial 165 finished with value: 131.27998821171587 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.002948611437302357, 'reg_lambda': 0.010860790216273283, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:28,964] Trial 166 finished with value: 131.27999005506769 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.002158290205578853, 'reg_lambda': 0.010764473951619972, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:29,937] Trial 167 finished with value: 132.01294450182561 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.12, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0026501274507407017, 'reg_lambda': 0.010398924924165245, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:31,013] Trial 168 finished with value: 131.49186928900602 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 140, 'reg_alpha': 0.0020090123578140142, 'reg_lambda': 0.008371806145388844, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:32,112] Trial 169 finished with value: 131.27998848837507 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0011595495581795479, 'reg_lambda': 0.010856314432088413, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:33,212] Trial 170 finished with value: 131.49191230861337 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 120, 'reg_alpha': 0.0010028986861267452, 'reg_lambda': 0.006112637017421583, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:34,287] Trial 171 finished with value: 131.27997596615137 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.001572768574935017, 'reg_lambda': 0.011540049625929815, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:35,353] Trial 172 finished with value: 131.27997347283534 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.002057998667654341, 'reg_lambda': 0.01167327318966983, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:36,596] Trial 173 finished with value: 131.25209277708856 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 140, 'reg_alpha': 0.0015326521495042213, 'reg_lambda': 0.010893699619838366, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:37,655] Trial 174 finished with value: 131.27998501762298 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0013135875381319422, 'reg_lambda': 0.011045512585035637, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:38,778] Trial 175 finished with value: 131.2799990959203 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0015313732665270725, 'reg_lambda': 0.010272917465077141, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:39,844] Trial 176 finished with value: 131.27998450065434 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.001110459804725861, 'reg_lambda': 0.011074975706827589, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:40,738] Trial 177 finished with value: 131.66026158343485 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 4, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0011958967680864138, 'reg_lambda': 0.010971101863348497, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:41,708] Trial 178 finished with value: 131.45604865224018 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0013609370606553972, 'reg_lambda': 0.00749290588335059, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:42,762] Trial 179 finished with value: 134.46782079730772 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 140, 'reg_alpha': 0.0016019427000381285, 'reg_lambda': 0.01147298981623992, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:43,896] Trial 180 finished with value: 131.4905717297941 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 460, 'num_leaves': 140, 'reg_alpha': 0.0014576622108216789, 'reg_lambda': 0.007230353087114428, 'subsample': 0.9}. Best is trial 135 with value: 131.22750304410494.
# [I 2025-10-10 10:09:44,920] Trial 181 finished with value: 131.22748444202844 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.0011274689216738674, 'reg_lambda': 0.011478646511407528, 'subsample': 0.9}. Best is trial 181 with value: 131.22748444202844.
# [I 2025-10-10 10:09:45,982] Trial 182 finished with value: 131.22748507683215 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.0010508345409726675, 'reg_lambda': 0.011434329034425626, 'subsample': 0.9}. Best is trial 181 with value: 131.22748444202844.
# [I 2025-10-10 10:09:47,091] Trial 183 finished with value: 131.62277284888341 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.0010631121059177014, 'reg_lambda': 0.07220289554415375, 'subsample': 0.9}. Best is trial 181 with value: 131.22748444202844.
# [I 2025-10-10 10:09:48,107] Trial 184 finished with value: 131.2274800813393 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.0012334316779300696, 'reg_lambda': 0.01178650108318784, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:49,188] Trial 185 finished with value: 131.2799734802472 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0011910897787572427, 'reg_lambda': 0.011677780418564074, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:50,250] Trial 186 finished with value: 131.5424328474156 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0011671089456911936, 'reg_lambda': 0.01999457059984047, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:51,320] Trial 187 finished with value: 131.45603552438814 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.001011153769716179, 'reg_lambda': 0.008247025298531536, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:52,763] Trial 188 finished with value: 132.14220483843158 and parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.08, 'max_depth': 6, 'n_estimators': 450, 'num_leaves': 140, 'reg_alpha': 0.0012324966207014388, 'reg_lambda': 0.013308635001971174, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:53,800] Trial 189 finished with value: 131.72369855769213 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 460, 'num_leaves': 140, 'reg_alpha': 0.001438512391856814, 'reg_lambda': 0.2549106102902572, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:54,864] Trial 190 finished with value: 132.22973147021108 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.04, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.0017102550238045555, 'reg_lambda': 0.012319370064782904, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:55,923] Trial 191 finished with value: 131.22748722895875 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.001206574650394495, 'reg_lambda': 0.011281329259743294, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:56,988] Trial 192 finished with value: 131.4560214676103 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0011953361651296976, 'reg_lambda': 0.009050038596852246, 'subsample': 0.9}. Best is trial 184 with value: 131.2274800813393.
# [I 2025-10-10 10:09:58,039] Trial 193 finished with value: 131.22747990515194 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.0016942045358212116, 'reg_lambda': 0.011795512437624799, 'subsample': 0.9}. Best is trial 193 with value: 131.22747990515194.
# [I 2025-10-10 10:09:59,134] Trial 194 finished with value: 131.5583084824992 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 430, 'num_leaves': 140, 'reg_alpha': 0.0015986686596274509, 'reg_lambda': 0.018740975695325093, 'subsample': 0.9}. Best is trial 193 with value: 131.22747990515194.
# [I 2025-10-10 10:10:00,257] Trial 195 finished with value: 131.25206899023863 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 140, 'reg_alpha': 0.0013530174444421617, 'reg_lambda': 0.012134982254782638, 'subsample': 0.9}. Best is trial 193 with value: 131.22747990515194.
# [I 2025-10-10 10:10:01,318] Trial 196 finished with value: 131.65230459278277 and parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 140, 'reg_alpha': 0.0013378611608654137, 'reg_lambda': 0.007557839123458403, 'subsample': 0.9}. Best is trial 193 with value: 131.22747990515194.
# [I 2025-10-10 10:10:02,413] Trial 197 finished with value: 131.38341218244722 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 440, 'num_leaves': 140, 'reg_alpha': 0.0021466809486103636, 'reg_lambda': 0.01237464860349062, 'subsample': 0.9}. Best is trial 193 with value: 131.22747990515194.
# [I 2025-10-10 10:10:03,524] Trial 198 finished with value: 131.49194465764404 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 450, 'num_leaves': 140, 'reg_alpha': 0.0017245735969885394, 'reg_lambda': 0.0044035264860821524, 'subsample': 0.7}. Best is trial 193 with value: 131.22747990515194.
# [I 2025-10-10 10:10:04,664] Trial 199 finished with value: 131.49059092822546 and parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.08, 'max_depth': 5, 'n_estimators': 460, 'num_leaves': 140, 'reg_alpha': 0.0010351815772337233, 'reg_lambda': 0.006328726252769847, 'subsample': 0.9}. Best is trial 193 with value: 131.22747990515194.

# %%
ml_pipeline = Pipeline([("preprocessor",prepro),("model", LGBMRegressor(**best_params))])
Y  = data[target]
X  = data[features]
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.2,random_state=42)

ml_pipeline.fit(train_x,train_y)

preds_train = ml_pipeline.predict(train_x)  
preds_test  = ml_pipeline.predict(test_x)  
r2_train = r2_score(train_y,preds_train)
r2_test = r2_score(test_y,preds_test)

# %%
print(f"R2 train {r2_train} ; R2 test {r2_test}")
# Out:
# R2 train 0.8369162058556024 ; R2 test 0.8155254451227416

# %% [markdown]
# A small overfitting but still very acceptable

# %% [markdown]
# ## Explicabilité avec shapeley

# %% [markdown]
# ### Calcul des valeurs du shapeley

# %%
import sklearn

def ComputeShapeleyValues(data:pd.DataFrame, 
                          features:str,
                          target:str,
                          model:sklearn.pipeline.Pipeline):
    """
    Calcule les valeurs du shapeley.

    Args:
        data (pandas dataframe): les données 
        feature: liste des facteur d'entrée
        target: nom de la variable modélisée
        model: pipeline sklearn (preporocesseur + regresseur)

    Returns:
        svals: valeurs du shapeley (dimension = [len(data), nbre features numérique + nbre de modalités de la variable catégorielle])
        df_x : pandas dataframe avec les features transformées même dimension que svals  

    """    
    # data: pandas datafra


    train_x = data[features]
    train_y = data[target]


    x_transformed = model.steps[0][1].transform(train_x)    # Ici je transforme "train_x" car shap ne peut pas intégrer directement des variables catégorielles
    if type(x_transformed) == scipy.sparse._csr.csr_matrix:
        x_transformed = np.asarray(x_transformed.todense())

    # Quelques manipulations pour récupérer les noms initiaux des features (qui ont été renommés par le transformeur)
    f_name = model.steps[0][1].get_feature_names_out()
    f_name = [f.replace('num__','').replace('cat__','') for f in f_name]

    regressor = model.steps[1][1] # on récupère le regresseur depuis le pipeline


    df_x = pd.DataFrame(index=train_x.index,data=x_transformed,columns=f_name) # pandas dataframe avec les features transformées


    # On crée un objet "explicateur" avec la librairie SHAP
    # On choisi un "TreeExplainer" qui est spécifiquement dédié (plus rapide) à l'explicabilité des modèles ensemblistes comme ce lgbm

    explainer = shap.TreeExplainer(regressor, 
                                   model_output='raw', 
                                   feature_perturbation='interventional')
    
    #model_output='raw' : SHAP calcule les contributions expliquant la valeur brute prédite par le modèle (avant transformation en probabilité).
    #feature_perturbation : définit comment SHAP simule l’effet de chaque variable lorsqu’on "perturbe" les entrées pour mesurer leur influence sur la prédiction.
    #feature_perturbation='interventional': C’est la version la plus rigoureuse : SHAP prend en compte les dépendances entre variables (corrélations).

    svals = explainer.shap_values(df_x, y=train_y)

    return svals, df_x

# %%
svals, df_x = ComputeShapeleyValues(data=data, 
                          features=features,
                          target=target,
                          model=ml_pipeline)

# %% [markdown]
# ### Visualisation

# %%
fig_shape_fact = plt.figure(facecolor="#c6dee8")
ax_shape = fig_shape_fact.axes
shap.summary_plot(svals, df_x,show=False)
plt.gca().tick_params(labelsize=10)
plt.gca().set_xlabel("Impact sur la variable modélisée", fontsize=14)

# %% [markdown]
# Le diagramme ci-dessous combine à la fois :
#
# - la force d’impact de chaque variable sur le modèle,
# - la direction de cet impact (positif ou négatif),
# - la valeur des features (haute ou basse).
#
# Lecture de l’axe horizontal
#
# L’axe des X représente la valeur SHAP (l'unité est la même que la variable modélisée kwh/kg): c’est l’impact d’une variable sur la prédiction finale du modèle.
# - Valeur SHAP positive → la variable augmente la prédiction (pousse vers une valeur plus élevée de la variable modélisée).
# - Valeur SHAP négative → la variable diminue la prédiction.
# - Zéro → pas d’impact sur la sortie du modèle pour cet échantillon.
#
# Lecture de l’axe vertical
#
# Chaque ligne correspond à une variable du modèle (feature). Elles sont triées par importance moyenne (du haut vers le bas).
# - var_dim1 et var_quality sont les plus influentes,
# - type_prod_40, type_prod_63, etc. ont un impact marginal.
#
# Interprétation des couleurs
#
# Les couleurs indiquent la valeur de la feature pour chaque observation :
# - Si les points rouges sont surtout à droite → une valeur élevée augmente la sortie.
# - Si les points rouges sont à gauche → une valeur élevée la diminue.
#
#
# Par exemple pour la variable "var_quality":
# - les points rouges sont plutôt à droite: une augmentation de la variable fait augmenter la consommation
# - Moins étendue que "var_dim1": influence un peu plus faible que "var_dim1"

# %% [markdown]
# ![Explicabilité détaillé des features](images/features_importance_detail.png)

# %% [markdown]
# ### Exploitation pour expliquer les variations de consommations entre 2 mois

# %%
df_shape = pd.DataFrame(data=svals,columns=df_x.columns)
df_shape.index = df_x.index
df_conso_mois = data[target].resample('MS').mean()
cols_types = [c for c in df_shape.columns if 'type_prod' in c]
cols_types.append('type_autres')
df_shape_type_aggrege = df_shape.copy()
df_shape_type_aggrege['type'] = df_shape_type_aggrege[cols_types].sum(axis=1)
df_shape_type_aggrege.drop(columns=cols_types,inplace=True)
df_shape_type_aggrege_mois = df_shape_type_aggrege.resample('MS').mean()

current_month  = "2025-07-01"
previous_month = "2025-06-01"

contributions_a_variation = df_shape_type_aggrege_mois.loc[current_month] - df_shape_type_aggrege_mois.loc[previous_month] 
conso_current_month       = df_conso_mois[current_month]
conso_previous_month      = df_conso_mois[previous_month]
part_unexplained          = conso_current_month - conso_previous_month - contributions_a_variation.sum()



x = ["Mois précédent"]     + contributions_a_variation.index.to_list() + ["Autre"] + ["Mois courant"]
y = [conso_previous_month] + contributions_a_variation.values.tolist() + [part_unexplained] +[conso_current_month]

fig = go.Figure(go.Waterfall(
    name="20",
    orientation="v",
    measure=["relative", "relative", "relative", "relative", "relative", "relative", "relative","total"],
    x=x,
    y=y,
    textposition="outside",
    connector={"line":{"color":"rgb(63, 63, 63)"}}
))

# Mise en forme
fig.update_layout(
      width=1000,      # Largeur en pixels
    height=600,     # Hauteur en pixels
    title="Variation de la consommation entre M-1 et M",
    xaxis_title="Facteur",
    yaxis_title="Consommation (kWh/kg)",
    yaxis=dict(range=[2000, 2800]),
    showlegend=False,
)

fig.show()

# %% [markdown]
# ![Explication variation conso](images/waterfall_explanation.png)
